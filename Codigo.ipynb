# %% [markdown]
# Comenzamos con las importaciones para poder manejar el dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_datos = pd.read_csv('USA_Housing.csv', sep=',')
df_datos.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
#Vemos tipos de datos
df_datos.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
# Limpiamos los datos
df_datos.isnull().sum()
df_datos.dropna(inplace=True)

# %% [markdown]
# Ahora comenzaremos con las graficas, en primer lugar con la matriz de correlacion o mapa de calor

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df_datos.corr(), annot=True, cmap="plasma")
plt.title("Matriz de correlacion")
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_2436\4073350687.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_datos.corr(), annot=True, cmap="plasma")

# %%
sns.pairplot(df_datos)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(df_datos)
plt.show()

# %%
# hacemos comparaciones entre las variables mediante graficos
sns.jointplot(x='Avg. Area Income', y='Price', data=df_datos) # comparamos el ingreso promedio con el precio
plt.show()

# %%
# hacemos mas comparaciones entre las variables haciendo graficos
sns.jointplot(x= 'Avg. Area House Age', y='Price', data=df_datos) # comparamos la eeddad y el precio
plt.show()

# %%
# comparamos la edad de la casa con el ingreso promedio
sns.jointplot(x='Avg. Area House Age', y='Avg. Area Income', data=df_datos)
plt.show()

# %%
#comparamos el numero de dormitorios con el precio
sns.jointplot(x='Avg. Area Number of Rooms', y='Price', data=df_datos)

# %%
# comparamos el ingreso promedio con el numero de dormitorios
sns.jointplot(x='Avg. Area Number of Rooms', y='Avg. Area Income', data=df_datos)
plt.show()

# %%
# comparamos el numero de dormitorios con el ingreso promedio
sns.jointplot(x='Avg. Area Number of Rooms', y='Avg. Area Number of Bedrooms', data=df_datos)
plt.show()

# %%
# comparamos el numero de dormitorios con el precio
sns.jointplot(x='Avg. Area Number of Bedrooms', y='Price', data=df_datos)
plt.show()

# %%
# comparamos el numero de dormitorios con la edad de la casa
sns.jointplot(x='Avg. Area Number of Bedrooms', y='Avg. Area House Age', data=df_datos)
plt.show()

# %%
# comparamos el numero de dormitorios con el numero de habitaciones
sns.jointplot(x='Avg. Area Number of Bedrooms', y='Avg. Area Number of Rooms', data=df_datos)
plt.show()
