# %% [markdown]
# Comenzamos con las importaciones para poder manejar el dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_datos = pd.read_csv('dataset_USA.csv')
df_datos.head()
# Out:
#                                     Avg. Area Income  Avg. Area House Age  \
# 0  79545.45857431678,5.682861321615587,7.00918814...                  NaN
# 1                          Laurabury, NE 37010-5101"                  NaN
# 2  79248.64245482568,6.0028998082752425,6.7308210...                  NaN
# 3                           Lake Kathleen, CA 48958"                  NaN
# 4  61287.067178656784,5.865889840310001,8.5127274...                  NaN
#
#    Avg. Area Number of Rooms  Avg. Area Number of Bedrooms  Area Population  \
# 0                        NaN                           NaN              NaN
# 1                        NaN                           NaN              NaN
# 2                        NaN                           NaN              NaN
# 3                        NaN                           NaN              NaN
# 4                        NaN                           NaN              NaN
#
#    Price  Address
# 0    NaN      NaN
# 1    NaN      NaN
# 2    NaN      NaN
# 3    NaN      NaN
# 4    NaN      NaN

# %%
#Vemos tipos de datos
df_datos.describe()
# Out:
#        Avg. Area House Age  Avg. Area Number of Rooms  \
# count                  0.0                        0.0
# mean                   NaN                        NaN
# std                    NaN                        NaN
# min                    NaN                        NaN
# 25%                    NaN                        NaN
# 50%                    NaN                        NaN
# 75%                    NaN                        NaN
# max                    NaN                        NaN
#
#        Avg. Area Number of Bedrooms  Area Population  Price  Address
# count                           0.0              0.0    0.0      0.0
# mean                            NaN              NaN    NaN      NaN
# std                             NaN              NaN    NaN      NaN
# min                             NaN              NaN    NaN      NaN
# 25%                             NaN              NaN    NaN      NaN
# 50%                             NaN              NaN    NaN      NaN
# 75%                             NaN              NaN    NaN      NaN
# max                             NaN              NaN    NaN      NaN

# %% [markdown]
# Ahora comenzaremos con las graficas, en primer lugar con la matriz de correlacion o mapa de calor

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df_datos.corr(), annot=True, cmap="YlGnBu")
plt.title("Matriz de correlacion/mapa de calor")
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_6924\1691064769.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_datos.corr(), annot=True, cmap="YlGnBu")
# c:\Users\Usuario\Documents\anaconda3\lib\site-packages\seaborn\matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# c:\Users\Usuario\Documents\anaconda3\lib\site-packages\seaborn\matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)

# %%
sns.pairplot(df_datos)
plt.show()

# %%
sns.violinplot(df_datos)
plt.show()
